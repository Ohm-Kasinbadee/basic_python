# %% [markdown]
# # Import Lib Pandas.

# %%
#########################
## import pandas as pd ##
#########################

# %% [markdown]
# # Read & Write File.
#
# ---

# %% [markdown]
# ref : https://phyblas.hinaboshi.com/yancham03

# %%
########## Read File CSV ##############
## df = pd.read_csv( <<FILE_NAME>> ) ##
#######################################
########## Parameters Option ##########
## sep อ่านไฟล์ด้วย ตัวขั้น                ##
## sep='' OR sep=',' OR sep='\s+'.   ##
#######################################
## na_values อ่านค่าเป็น NAN            ##
## na_values=['ไม่มีข้อมูล','-']         ##
#######################################

########## Write File CSV ########################
## df = pd.read_csv(<<FILE_NAME>>, index_col=0) ##
##################################################

# %% [markdown]
# # Select Info Data Frame.
#
#
# ---

# %%
############################
## df.info()              ##
############################
## df.empty               ##
############################
## list(df.columns)       ## -> clean columns |' a' -> 'a'| >> df.rename(columns=lambda x: x.strip())
############################
## df.head(5)             ##
############################
## df.shape               ##
############################
## df.isnull().sum()      ##
############################
## df.dtypes.             ##
############################
## df.describe()          ##
############################
## df["<<COLUMNS NAME>>"] ##
############################

# %% [markdown]
# # Clean data setup.

# %%
################################################################
## df.dropna(inplace = True)                                  ## removing null values to avoid errors.
################################################################
## df["<<COLUMNS NAME>>"].str.lower()                         ## converting values lower in column.
################################################################
## df["<<COLUMNS NAME>>"].str.upper()                         ## converting values upper in column.
################################################################
## df["<<COLUMNS NAME>>"].str.split(sep=" ")                  ## split keyword in column.
################################################################
## df["<<COLUMNS NAME>>"].str.replace(sep=" ", expand = True) ## replace woed in column. ex. [ df['age'].replace(' ', np.NaN) ]
################################################################
## df["<<COLUMNS NAME>>"].str.strip()                         ## remove spaces in column. >> ex.[' a' to 'a']
################################################################
## df["<<COLUMNS NAME>>"].str.lstrip('.,-')                   ## removed space string.
################################################################
## df.drop(columns=" <<COLUMNS NAME >> ")
################################################################

# %% [markdown]
# Pandas str methods: https://www.geeksforgeeks.org/python-pandas-working-with-text-data/

# %%
import pandas as pd
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'], 
        'Age':[27, 24, 22, 32], 
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Knnuaj'], 
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']} 

df = pd.DataFrame(data)

    
# # dropping null value columns to avoid errors 
# df.dropna(inplace = True) 
    
# # new data frame with split value columns 
# df["Address"]= df["Address"].str.split("a", expand = True) 
   
# # df display 
# print(df)
