# %% [markdown]
# ![bandicam 2021-12-08 19-46-01-898.jpg](data:image/jpeg;base64,...)

# %%
#1 
def my_function1(data1):
  int1 = 0
  while int1 < len(list1):
    if (int1%2) != (int(list1[int1])%2):
      return 'False'
      break
    int1 += 1
  return 'True'
input1 = str(input())
list1 = input1.split(',')
print(my_function1(list1))
# Out:
# 2,7,8,8,6,1,6,3
# False

# %% [markdown]
# ![bandicam 2021-12-08 19-46-12-805.jpg](data:image/jpeg;base64,...)

# %%
#2
input2 = int(input())
if (input2%3) == 0 and  (input2%5) == 0:
  print('FizzBuzz')
elif (input2%5) == 0:
  print('Buzz')
elif (input2%3) == 0:
  print('Fizz')
else:
  print(input2)
# Out:
# 4
# 4

# %% [markdown]
# ![bandicam 2021-12-08 19-46-32-632.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![bandicam 2021-12-08 19-46-50-179.jpg](data:image/jpeg;base64,...)

# %%
#3
input3_1 = str(input())
input3_2 = int(input())
int3 = 0
if not input3_1:
  print('The string is empty')
else:
  if len(input3_1) < input3_2:
    print('Out or range')
  elif input3_2 == 0:
    print('The number of substring is zero.')
  elif input3_2 < 0:
    print('The number of substring cannot be zero.')
  else:
    while int3 < len(input3_1):
      num3 = input3_1[int3:int3+input3_2]
      if len(num3) == input3_2:
        print(num3)
      int3 += 1
# Out:
# 1
# The string is empty

# %% [markdown]
# ![bandicam 2021-12-08 19-47-00-430.jpg](data:image/jpeg;base64,...)

# %%
#4
input4 = str(input()).lower()
data4 = input4.replace(" ", "")
pangram =list("abcdefghijklmnopqrstuvwxyz")
for dt3 in pangram:
  if dt3 in data4:
    ex3 = 'True'
  else:
    ex3 = 'False'
    break
print(ex3)
#The quick brown fox jumps over the lazy dog
# Out:
# The quick brown fox jumps over the lazy dog
# True

# %% [markdown]
# ![bandicam 2021-12-08 19-47-33-487.jpg](data:image/jpeg;base64,...)

# %%
#5
def my_function5(input5):
  h5 = 1
  list5 = []
  for data5 in input5:
    if data5.isnumeric()  == True:
      num5 = int(data5)*h5
      list5.append(num5)
    else:
      num5 = int(10)*h5
      list5.append(num5)
    h5+=1
  return list5
input5 = str(input()).replace('-','').split()
if (sum(my_function5(input5[0]))%11) == 0:
  print('True')
else:
  print('False')
# Out:
# 3-598-21507-A
# True

# %% [markdown]
# ![bandicam 2021-12-08 19-47-44-674.jpg](data:image/jpeg;base64,...)

# %%
#6
input6_1 = str(input()).split(',')
input6_2 = str(input())
count6 = input6_1.count(input6_2)
list6 = []
for in6 in input6_1:
  # print(in6)
  if in6 != input6_2:
    list6.append(in6)
for in6_2 in range(count6):
  list6.append(input6_2)
print(','.join(list6))
# Out:
# 7,8,9,1,2,3,4
# 9
# 7,8,1,2,3,4,9

# %% [markdown]
# ![bandicam 2021-12-08 19-47-55-741.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![bandicam 2021-12-08 19-48-05-592.jpg](data:image/jpeg;base64,...)

# %%
#7
input7 = str(input()).split(' ')
list7=[]
#20.3k 3.8k 7.7k 992
for data7 in input7:
  if data7[-1] == 'k':
    da7=data7[0:-1].replace('.','')
    list7.append(str(da7+'00')) 
  else:
    list7.append(data7) 
print(' '.join(list7))
# Out:
# 5.5k 8.9k 32
# 5500 8900 32

# %% [markdown]
# ![bandicam 2021-12-08 19-48-14-244.jpg](data:image/jpeg;base64,...)

# %%
#8
input8_1 = str(input()).split(',')
input8_2 = str(input()).split(',')
list8=[]
for data8 in range(0,len(input8_1)):
  num8 = int(input8_1[data8])+int(input8_2[data8])
  list8.append(num8)
if len(set(list8)) == 1:
  print('True')
else:
  print('False')
# Out:
# 1,2
# -1,-1
# False

# %% [markdown]
# ![bandicam 2021-12-08 19-48-23-563.jpg](data:image/jpeg;base64,...)

# %%
#9
input9 = str(input()).split(',')
list9_1 =[]
for data9 in input9:
  list9_1.append(len(data9))
  print(data9)
input9.sort()
print(input9)
# Out:
# this,is,a,small,test
# this
# is
# a
# small
# test
# ['a', 'is', 'small', 'test', 'this']

# %% [markdown]
# ![bandicam 2021-12-08 19-48-32-429.jpg](data:image/jpeg;base64,...)

# %%
# 10
input10 = str(input()).split()
list10 =[str(input10[0])]
num10_1 =int(input10[0])/2
while num10_1 > int(input10[1]):
  list10.append(str(num10_1))
  num10_1 = num10_1/2
print(' -> '.join(list10))
print(len(list10)-1)
# Out:
# 1324 98
# 1324 -> 662.0 -> 331.0 -> 165.5
# 3

# %% [markdown]
# ![bandicam 2021-12-08 19-48-40-452.jpg](data:image/jpeg;base64,...)

# %%
#11
input11 = str(input()).split('/')
print(''.join(input11[::-1]))
# Out:
# 12/31/2019
# 20193112

# %% [markdown]
# ![bandicam 2021-12-08 19-48-51-047.jpg](data:image/jpeg;base64,...)

# %%
# 12
import calendar
def my_function12(data12):
  date12  = calendar.TextCalendar(firstweekday = 0) 
  list12 = []
  i12 = 1
  while i12 <= 12:
    year = data12
    width = i12
    day12 = date12.monthdayscalendar(year, width)
    for f12 in day12:
        list12.append(f12[4])
    i12 += 1
  num12 = list12.count(13)
  return num12
input12 = int(input())
print(my_function12(input12))
# Out:
# 16
# 1

# %% [markdown]
# ![bandicam 2021-12-08 19-49-00-058.jpg](data:image/jpeg;base64,...)

# %%
#13
import json
def my_function13(data13):
  dic13 = dict()
  num13 = 0
  for in13 in data13:
    in13 = str(in13)
    if in13 not in dic13:
      list13 = []
      dic13[in13] = list13
      list13.append(num13)
    else:
      list13 = dic13[in13]
      list13.append(num13)
      dic13[in13] = list13
    num13+=1
  return dic13
input13 = str(input())
print(my_function13(input13))
# Out:
# froggy
# {'f': [0], 'r': [1], 'o': [2], 'g': [3, 4], 'y': [5]}

# %% [markdown]
# ![bandicam 2021-12-08 19-49-10-448.jpg](data:image/jpeg;base64,...)

# %%
#14
import re
input14 = ' '+str(input()).upper().replace('_','')
data14 = re.findall(r'\s[a-zA-Z]',input14)
dt14 = "".join(data14).replace(' ','')
print(dt14)
# Out:
# The Road _Not_ Taken
# TRNT

# %% [markdown]
# ![bandicam 2021-12-08 19-50-56-542.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![bandicam 2021-12-08 19-51-05-605.jpg](data:image/jpeg;base64,...)

# %%
#15

def my_function15(da15_1,da15_2): 
  if da15_1 == da15_2:
    return 1
  else:
    return 0

dict15 = dict()
input15 = ''
score15 = {"win":3,"draw":1,"loss": 0}
while input15 != 'end' :
  input15=str(input())
  if input15 != 'end':
    input15_=input15.split(';')
    i15 = 0
    while i15 < 2:
      da2 = input15_[2]
      if input15_[i15] in dict15:
        child15 = {"Competitor":input15_[i15], "MP": dict15[input15_[i15]]["MP"]+1,"W":my_function15( da2,'win') +dict15[input15_[i15]]["W"],"D" :my_function15( da2,'draw')+dict15[input15_[i15]]["D"] ,"L" :my_function15( da2,'loss')+dict15[input15_[i15]]["L"],"P": (score15[da2]*1)+dict15[input15_[i15]]["P"]}
        dict15[input15_[i15]] =child15
      else:
        child15 = {"Competitor":input15_[i15], "MP": 1,"W":my_function15( da2,'win') ,"D" :my_function15( da2,'draw') ,"L" :my_function15( da2,'loss'),"P": (score15[da2]*1)}
        dict15[input15_[i15]] =child15
      i15 += 1
else:
  print( "{:30}|{:2}|{:2}|{:2}|{:2}|{:2}".format('Competitor','MP','W','D','L','P'))
  for x15 in dict15:
    print( "{:30}|{:2}|{:2}|{:2}|{:2}|{:2}".format(dict15[x15]['Competitor'],dict15[x15]['MP'],dict15[x15]['W'],dict15[x15]['D'],dict15[x15]['L'],dict15[x15]['P']))
  # print(dict15)
# Stringformat"{:30}|{:2}|{:2s}|{:2s}|{:2s}|{:2s}".format(...)
# Sam;Adam;draw
# Anna;Tina;draw
# Anna;Sam;win
# Tina;Adam;loss
# Adam;Anna;loss
# Sam;Tina;loss
# Out:
# Adam;Anna;loss
# Tina;Adam;loss
# Anna;Tina;draw
# Anna;Sam;win
# end
# Competitor                    |MP|W |D |L |P
# Adam                          | 2| 0| 0| 2| 0
# Anna                          | 3| 1| 1| 1| 4
# Tina                          | 2| 0| 1| 1| 1
# Sam                           | 1| 1| 0| 0| 3
