# %% [markdown]
# list, tuple, set, dict, python package, file

# %% [markdown]
# ![bandicam 2021-12-08 18-56-14-018.jpg](data:image/jpeg;base64,...)

# %%
#1
from statistics import median
input1 = str(input())
input1= input1.split(',')
input1=[int(num1) for num1 in input1]
input1.sort()
median1 = median(input1)
print(median1)
#print(input1)
# Out:
# 1,4,2,4
# 3.0

# %% [markdown]
# ![bandicam 2021-12-08 18-56-22-719.jpg](data:image/jpeg;base64,...)

# %%
#2
input2 = str(input())
input2= input2.split(',')
input2=[int(num2) for num2 in input2]
input2.sort()
#print(input2)
print("Uniquelist"+str(list(set(input2))))
print("Minimumnumberis:"+str(min(input2)))
print("Maximumnumberis:"+str(max(input2)))
# Out:
# 87,45,41,65,94,41,99,94
# Uniquelist[65, 99, 41, 45, 87, 94]
# Minimumnumberis:41
# Maximumnumberis:99

# %% [markdown]
# ![bandicam 2021-12-08 18-56-29-686.jpg](data:image/jpeg;base64,...)

# %%
#3
input3 = str(input())
input3= input3.split(',')
#input2=[int(num3) for num3 in input3]
num3_1 = input3[0:3]
num3_2 = input3[3:6]
num3_3 = input3[6:]
print("Chunk 1 "+str(num3_1)+" reversing "+str(num3_1[::-1]))
print("Chunk 2 "+str(num3_2)+" reversing "+str(num3_2[::-1]))
print("Chunk 3 "+str(num3_3)+" reversing "+str(num3_3[::-1]))
# Out:
# 11,45,8,23,14,12,78,45,89,12,21
# Chunk 1 ['11', '45', '8'] reversing ['8', '45', '11']
# Chunk 2 ['23', '14', '12'] reversing ['12', '14', '23']
# Chunk 3 ['78', '45', '89', '12', '21'] reversing ['21', '12', '89', '45', '78']

# %% [markdown]
# ![bandicam 2021-12-08 18-56-39-131.jpg](data:image/jpeg;base64,...)

# %%
#4
input4_1 = str(input()).split(',')
input4_2 = str(input()).split(',')
#print(input4_1)
#print(input4_2)
list1 = []
for data1 in input4_1:
  for data2 in input4_2:
    list1.append(data1+' '+data2)
print(list1)
# Out:
# Cat,Dog,Bat
# White,Black,Red
# ['Cat White', 'Cat Black', 'Cat Red', 'Dog White', 'Dog Black', 'Dog Red', 'Bat White', 'Bat Black', 'Bat Red']

# %% [markdown]
# ![bandicam 2021-12-08 18-56-48-630.jpg](data:image/jpeg;base64,...)

# %%
#5
input5_1 = str(input()).split(',')
input5_2 = str(input()).split(',')
if len(input5_1) == len(input5_2):
 list5_1 = []
 for num5 in range(0,len(input5_1)):
  list5_2 = []
  list5_2.append(input5_1[num5])
  list5_2.append(input5_2[num5])
  #print(list5_2)
  list5_1.append(tuple(list5_2))
 print(tuple(list5_1))
else:
 print('Out of range')
#4,9,16,25,36,49,64
#2,3,4,5,6,7,8
# Out:
# 4,9,16,25,36,49,64
# 2,3,4,5,6,7,8
# (('4', '2'), ('9', '3'), ('16', '4'), ('25', '5'), ('36', '6'), ('49', '7'), ('64', '8'))

# %% [markdown]
# ![bandicam 2021-12-08 18-57-00-146.jpg](data:image/jpeg;base64,...)

# %%
#6
data6={"shrimp":15,"dog":10,"cat":50,"bat":30,"tots":12}
list6_1 = []
for x, y in data6.items():
 list6_2 = []
 list6_2.append(x)
 list6_2.append(y)
 list6_1.append(list6_2)
 #print(list6_2)
print(list6_1)
# Out:
# [['shrimp', 15], ['dog', 10], ['cat', 50], ['bat', 30], ['tots', 12]]

# %% [markdown]
# ![bandicam 2021-12-08 18-57-16-664.jpg](data:image/jpeg;base64,...)

# %%
#7
input7_2 = ''
input7_1=int(input())
list7= list(range(1,int(input7_1)+1))
#print(list7)
while input7_2 != 'x' :
  input7_2=str(input())
  if input7_2 == 'f':
    del list7[0]
    print("remove at first "+str(list7))
  elif input7_2 == 'l':
    list7.pop()
    print("remove at list "+str(list7))
  elif input7_2 == 'm':
    num7 =len(list7)
    if (int(num7)%2)==0:
     del list7[int(num7/2)-1]
    else:
     del list7[int(num7/2)]
    print("remove at middle "+str(list7))
  if len(list7) == 0:
    print("empty list")
    break
else:
 print("stop "+str(list7))
# Out:
# 2
# m
# remove at middle [2]
# l
# remove at list []
# empty list

# %% [markdown]
# ![bandicam 2021-12-08 18-57-34-238.jpg](data:image/jpeg;base64,...)

# %%
#8
input8_1 = set(str(input()).split(','))
input8_2 = set(str(input()).split(','))
list8 =list(input8_1)+list(input8_2)
list8_=[]
#print(list8)
for num8 in input8_1:
  if num8 not in input8_2:
   list8_.append(num8)
for num8 in input8_2:
  if num8 not in input8_1:
   list8_.append(num8)
print(list8_)
#10,20,30,40,50
#30,40,50,60,70
# Out:
# 10,20,30,40,50
# 30,40,50,60,70
# ['20', '10', '70', '60']

# %% [markdown]
# ![bandicam 2021-12-08 18-57-39-811.jpg](data:image/jpeg;base64,...)

# %%
#9
data9 = list((('a',540),('b',370),('c',101),('d',129),('c',50),('d',98),('e',98),('f',300)))
data9.sort(key = lambda x: float(x[1]), reverse = True)
print(tuple(data9))
# Out:
# (('a', 540), ('b', 370), ('f', 300), ('d', 129), ('c', 101), ('d', 98), ('e', 98), ('c', 50))

# %% [markdown]
# ![bandicam 2021-12-08 18-57-46-725.jpg](data:image/jpeg;base64,...)

# %%
#10
input10_1 = str(input()).split(',')
input10_2 = str(input()).split(',')
data10={}
for num10 in range(0,len(input10_1)):
  data10[input10_1[num10]] =input10_2[num10]
print(data10)
#Cat,Dog,Bat
#3,6,10
# Out:
# Cat,Dog,Bat
# 3,6,10
# {'Cat': '3', 'Dog': '6', 'Bat': '10'}

# %% [markdown]
# ![bandicam 2021-12-08 18-57-59-517.jpg](data:image/jpeg;base64,...)

# %%
#11
def binary(in11):
 data11 ={'0':'0000','1':'0001','2':'0010','3':'0011','4':'0100','5':'0101','6':'0110','7':'0111','8':'1000','9':'1001','A':'1010','B':'1011','C':'1100','D':'1101','E':'1110','F':'1111'}
 in11_1 = list(in11)
 nlist11 = []
 for da11 in in11_1:
   nlist11.append(data11[str(da11)])
 return ''.join(nlist11)
input11 = str(input())
print(binary(input11))
#1101 1001 1111 1010 0101 0011
# Out:
# 35AF9D
# 001101011010111110011101

# %% [markdown]
# ![bandicam 2021-12-08 18-58-11-305.jpg](data:image/jpeg;base64,...)

# %%
#12
input12_1 = str(input()).lower().split()
input12_2 = str(input()).lower()
#print(input12_1)
list12 = []
for data12 in input12_1:
  count12 = data12.count(input12_2)
  list12.append(count12)
print(list12)
#She sells sea shells by the seashore
#Peter Piper picked a peck of pickled peppers.
#She hiked in the morning, then swam in the river
# Out:
# She hiked in the morning, then swam in the river
# t
# [0, 0, 0, 1, 0, 1, 0, 0, 1, 0]

# %% [markdown]
# ![bandicam 2021-12-08 18-58-35-750.jpg](data:image/jpeg;base64,...)

# %%
#13
input13 = str(input()).split(',')
#print(input13)
list13=[]
for num13 in range(0,len(input13)):
#  print(str(input13[int(num13-1)])+'>'+str(input13[int(num13)]))
#  print(num13) 
 if num13 == 0:
  if input13[int(num13)+1] < input13[int(num13)]:
   list13.append(input13[int(num13)])
 elif num13 != len(input13)-1:
  if input13[int(num13)-1] < input13[int(num13)] and input13[int(num13)+1] < input13[int(num13)] :
   list13.append(input13[int(num13)])
print(list13)
# Out:
# 4,5,2,1,4,9,7,2
# ['5', '9']

# %% [markdown]
# ![bandicam 2021-12-08 18-58-40-909.jpg](data:image/jpeg;base64,...)

# %%
#14
input14 = str(input())
input14_s = set(list(input14))
num14=0
for data14 in input14_s:
 count14 = input14.count(data14)
 #print(data14)
 if (count14%2) == 0:
  #print(count14)
  num14+=count14
 #print(count14)
print(int(num14/2))
# Out:
# ABABC
# 2

# %% [markdown]
# ![bandicam 2021-12-08 18-59-00-753.jpg](data:image/jpeg;base64,...)![bandicam 2021-12-08 18-58-47-740.jpg](data:image/jpeg;base64,...)

# %%
#15
input15_1 = list(str(input()))
input15_2 = list(str(input()))
list15 = []
i = 0
while i < len(input15_1):
  if input15_1[i] != input15_2[i]:
    if input15_1[i] not in list15:
     list15.append(input15_1[i])
  i += 1
print(list(list15))
#happy birthday
#hawwy birthday
# Out:
# beethoven
# affthoif5
# ['b', 'e', 'v', 'n']

# %% [markdown]
# ![bandicam 2021-12-08 18-59-07-317.jpg](data:image/jpeg;base64,...)

# %%
#16
data16 = open("data1.txt", "r")
data16_1 = data16.read().split()
data16_2 = data16_1.count("Tools")
print(data16_2)
# Out:
# 7

# %% [markdown]
# ![bandicam 2021-12-08 18-59-13-905.jpg](data:image/jpeg;base64,...)

# %%
#17
data17 = open("data2.txt", "r")
data17_1 = data17.read().split()
for data17 in data17_1:
 #print(data17)
 if data17.replace(",","").isnumeric():
  print(data17)
# Out:
# 99
# 300,000
# 75,000
# 40,000
# 1
# 75
# 55
# 300
# 1,000,000
# 15,000,000

# %% [markdown]
# ![bandicam 2021-12-08 18-59-21-186.jpg](data:image/jpeg;base64,...)

# %%
#18
import json
data18 = open("jsonData1.json", "r")
data18_1 = data18.read()
data18_2 = json.loads(data18_1)
strings18=0
number18=0
list18=0
dict18=0
for x18, y18 in data18_2.items():
  type18 = type(y18)
  if isinstance(y18, str):
    strings18+=1
  if isinstance(y18, int):
    number18+=1
  if isinstance(y18, list):
    list18+=1
  if isinstance(y18, dict):
    dict18+=1
print("count strings type "+str(strings18))
print("count number type "+str(number18))
print("count list type "+str(list18))
print("count dict type "+str(dict18))
# Out:
# count strings type 15
# count number type 3
# count list type 3
# count dict type 1

# %% [markdown]
# ![bandicam 2021-12-08 18-59-28-792.jpg](data:image/jpeg;base64,...)

# %%
#19
import json
data19 = open("jsonData2.json", "r")
data19_1 = data19.read()
data19_2 = json.loads(data19_1)
number19=0
for list19 in data19_2:
 for x19, y19 in list19.items():
  if str(x19) == 'mobileParadigm':
   if isinstance(y19, int):
     if (y19%2)==0:
      number19+=1
print(number19)
# Out:
# 24

# %% [markdown]
# ![bandicam 2021-12-08 18-59-45-907.jpg](data:image/jpeg;base64,...)

# %%
#20
#data20 = [{"age":14,"grnder":"female","eyecolor":"Black","name":{"first":"AAA":"last":"AAAL"}},{"age":20,"grnder":"female","eyecolor":"Red","name":{"first":"BBB":"last":"BBBL"}},{"age":19,"grnder":"male","eyecolor":"Black","name":{"first":"CCC":"last":"BBBL"}},{"age":30,"grnder":"female","eyecolor":"Blue","name":{"first":"DDD":"last":"DDDL"}},{"age":26,"grnder":"male","eyecolor":"Black","name":{"first":"EEE":"last":"EEEL"}}]
f = open("jsonData3.json", "w")
f.write('[{"age":14,"grnder":"female","eyecolor":"Black","name":{"first":"AAA","last":"AAAL"}},{"age":20,"grnder":"female","eyecolor":"Red","name":{"first":"BBB","last":"BBBL"}},{"age":19,"grnder":"male","eyecolor":"Black","name":{"first":"CCC","last":"BBBL"}},{"age":30,"grnder":"female","eyecolor":"Blue","name":{"first":"DDD","last":"DDDL"}},{"age":26,"grnder":"male","eyecolor":"Black","name":{"first":"EEE","last":"EEEL"}}]')
f.close()
# print(data20)
