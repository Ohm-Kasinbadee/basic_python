# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ![bandicam 2021-12-08 18-40-11-143.jpg](data:image/jpeg;base64,...)

# %%
#1
in1= input()
in1 = int(in1)
#pi=22/7 หรือ 3.14
#pi*r^2
sum1 = 22/7 * (in1* in1)
print(sum1)
# Out:
# 12
# 452.57142857142856

# %% [markdown]
# ![bandicam 2021-12-08 18-40-17-944.jpg](data:image/jpeg;base64,...)

# %%
#2
in2 = input()
innum2 = int(in2)
if innum2 >=0 and innum2<=9:
  in2 = str(in2)
  e1=in2*1
  e2=in2*2
  e3=in2*3
  e1 = int(e1)#n
  e2 = int(e2)#nn
  e3 = int(e3)#nnn
  sum2=e1+e2+e3#n+nn+nnn
  print(sum2)
# Out:
# 5
# 615

# %% [markdown]
# ![bandicam 2021-12-08 18-40-25-619.jpg](data:image/jpeg;base64,...)

# %%
#3
x = input()
y = input()
x = int(x)
y = int(y)
s = (x+y)*(y+x)
s=str(s)
y=str(y)
x=str(x)
print('('+x+'+'+y+')*('+y+'+'+x+')='+s)
# Out:
# 4
# 3
# (4+3)*(3+4)=49

# %% [markdown]
# ![bandicam 2021-12-08 18-40-31-530.jpg](data:image/jpeg;base64,...)

# %%
#4
in4 = input()
in4 = str(in4)
j =  int(len(in4))
f=[]
for i in range(len(in4)):
  if (i%2) != 0:
    #print(i,in4[i])
    f.append(in4[i])
print(''.join(f))
# Out:
# ABCDE
# 1 B
# 3 D
# BD

# %% [markdown]
# ![bandicam 2021-12-08 18-40-37-814.jpg](data:image/jpeg;base64,...)

# %%
#5
in5 = input()
in5 = str(in5)
num5 = in5.upper()
num5 = num5.replace(" ","")
print(num5)
# Out:
# HeLlo World !!!
# HELLOWORLD!!!

# %% [markdown]
# ![bandicam 2021-12-08 18-40-46-601.jpg](data:image/jpeg;base64,...)

# %%
#6
in6 = input()
in6 = str(in6)
data = "JABCDEFGHI"
f6=[]
for i in range(len(in6)):
  #print(i,in1[i])
  #print(in1[i].isnumeric())
  if in6[i].isnumeric() == True:
    t = int(in6[i])
    f6.append(data[t])
  else:
    f6.append(in6[i])
#print(f6)
print(''.join(f6))
# Out:
# 1133557799
# AACCEEGGII

# %% [markdown]
# ![bandicam 2021-12-08 18-41-00-560.jpg](data:image/jpeg;base64,...)

# %%
#7
in7 = input()
in7 = str(in7)
txt7 = in7[::-1]
print(txt7)
# Out:
# abcdef
# fedcba

# %% [markdown]
# ![bandicam 2021-12-08 18-41-07-050.jpg](data:image/jpeg;base64,...)

# %%
#8
in8_1 = input()
in8_1 = str(in8_1)
in8_2 = input()
in8_2 = str(in8_2)
j8 =  int(len(in8_1))
j8_1=-(j8-2)
k8 =  int(len(in8_2))
k8_1=-(k8-2)
d8_1 = in8_1.replace(in8_1[0:j8_1],"")
d8_2 = in8_1.replace(d8_1,"")
c8_1 = in8_2.replace(in8_2[0:k8_1],"")
c8_2 = in8_2.replace(c8_1,"")
print(c8_2+d8_1+' '+d8_2+c8_1)
# Out:
# facebook
# twitter
# twcebook faitter

# %% [markdown]
# ![bandicam 2021-12-08 18-41-18-598.jpg](data:image/jpeg;base64,...)

# %%
#9
in91 = input()
in91 = str(in91)
in93 = len(in91)
in93 = int(in93)

a9 = in91.endswith('ing')
a9 = str(a9)
if a9 == 'True':
  print(in91+'ly')
else:
  if in93 >= 3:
    print(in91+'ing')
  else:
    exit()
# Out:
# string
# stringly

# %% [markdown]
# ![bandicam 2021-12-08 18-41-30-451.jpg](data:image/jpeg;base64,...)

# %%
#10
in10 = input()
in10 = str(in10).title()
in10_1 = in10.split(',')
in10_2 = list(set(in10_1))
in10_2.sort()
print(','.join(in10_2))
# Out:
# Hello,World,Hello,Ant
# Ant,Hello,World

# %% [markdown]
# ![bandicam 2021-12-08 18-41-39-509.jpg](data:image/jpeg;base64,...)

# %%
#11
in11 = input()
#in1 = str(in1)
b2 = in11.split(',')
b3=list(set(b2))
for i in b3:
  r = b2.count(i)
  i=str(i)
  if r>1:
    print(i+": 'duplicate'")
  else:
    print(i+": 'nonduplicate'")
# Out:
# 10,23,434,12,10,23,50
# 23: 'duplicate'
# 12: 'nonduplicate'
# 50: 'nonduplicate'
# 10: 'duplicate'
# 434: 'nonduplicate'

# %% [markdown]
# ![bandicam 2021-12-08 18-41-51-400.jpg](data:image/jpeg;base64,...)

# %%
#12
in1 = input()
in1 = str(in1)
txt = str(in1[::-1])
if txt == in1:
  print('This word is a palindrome')
else:
  print('This word is not a palindrome')
# Out:
# level
# This word is a palindrome

# %% [markdown]
# ![bandicam 2021-12-08 18-42-49-826.jpg](data:image/jpeg;base64,...)

# %%
#13
in13 = input()
in13 = int(in13)
w13=int(1)
num13 = []
for i13 in range(1,in13+1):
  t13=str(float(in13/i13).is_integer())
  if t13 == 'True':
    num13.append(i13)
print(num13)
# Out:
# 26
# [1, 2, 13, 26]

# %% [markdown]
# ![bandicam 2021-12-08 18-42-59-574.jpg](data:image/jpeg;base64,...)

# %%
#14
in14 = input()
in14 = int(in14)
w14=int(1)
num14 = []
for i14 in range(1,in14+1):
  w14*=i14
  #print(w)
  i14=str(i14)
  num14.append(i14)
# w14 = str(w14)
# print(w14)
#print(num14)
print('X'.join(num14)+' = '+w14)
# Out:
# 8
# 1X2X3X4X5X6X7X8 = 40320

# %% [markdown]
# ![bandicam 2021-12-08 18-43-11-908.jpg](data:image/jpeg;base64,...)

# %%
#15
in1 = input()
in1 = int(in1)
in2 = 'Python'
if in1 <= 5:
  o= str(in2[in1])
  d2 = in2.replace(o,"")
  print(d2)
else:
  print('Out of range')
# Out:
# 9
# Out of range
